# %%
# %matplotlib widget

# %%
import sys
sys.path.insert(0, '.')

import numpy as np
import matplotlib.pyplot as plt
from matplotly import matplotly

# %% [markdown]
# ## Test 1 — Single histogram

# %%
rng = np.random.default_rng(42)

fig, ax = plt.subplots(figsize=(7, 5))

x = rng.normal(0, 1, 1000)
ax.hist(x, bins=30, alpha=0.7, label='Normal(0,1)')

ax.set_title('Single Histogram')
ax.set_xlabel('Value')
ax.set_ylabel('Count')
ax.legend()

matplotly(fig)
# Out:
# VBox(children=(VBox(children=(HBox(children=(Button(description='Undo', disabled=True, icon='undo', layout=Lay…

# %%
rng = np.random.default_rng(42)

fig, ax = plt.subplots(figsize=(7, 5))

x = rng.normal(0, 1, 1000)
ax.hist(x, bins=30, alpha=0.7, label='Normal(0,1)')

ax.set_title('Single Histogram')
ax.set_xlabel('Value')
ax.set_ylabel('Count')
ax.legend()

# Generated by matplotly

# Remove original histogram patches
for _ in range(30):
    if ax.patches:
        ax.patches[0].remove()

# Histogram: Normal(0,1)
_hist_data = np.array([-3.6484, -2.9657, -2.8519, -2.7381, -2.6623, -2.5864, -2.5105, -2.4821, -2.4536, -2.4252, -2.3967, -2.3683, -2.3399, -2.3114, -2.283, -2.2545, -2.2261, -2.1976, -2.1692, -2.1407, -2.1123, -2.0838, -2.0554, -2.0391, -2.0229, -2.0066, -1.9904, -1.9741, -1.9579, -1.9416, -1.9253, -1.9091, -1.8928, -1.8766, -1.8603, -1.8441, -1.8278, -1.8175, -1.8071, -1.7968, -1.7864, -1.7761, -1.7657, -1.7554, -1.7451, -1.7347, -1.7244, -1.714, -1.7037, -1.6933, -1.683, -1.6726, -1.6623, -1.652, -1.6416, -1.6313, -1.6209, -1.6106, -1.6002, -1.5931, -1.586, -1.5789, -1.5718, -1.5647, -1.5576, -1.5505, -1.5433, -1.5362, -1.5291, -1.522, -1.5149, -1.5078, -1.5007, -1.4936, -1.4864, -1.4793, -1.4722, -1.4651, -1.458, -1.4509, -1.4438, -1.4367, -1.4296, -1.4224, -1.4153, -1.4082, -1.4011, -1.394, -1.3869, -1.3798, -1.3727, -1.3667, -1.3607, -1.3547, -1.3487, -1.3427, -1.3367, -1.3307, -1.3247, -1.3188, -1.3128, -1.3068, -1.3008, -1.2948, -1.2888, -1.2828, -1.2768, -1.2708, -1.2649, -1.2589, -1.2529, -1.2469, -1.2409, -1.2349, -1.2289, -1.2229, -1.2169, -1.211, -1.205, -1.199, -1.193, -1.187, -1.181, -1.175, -1.169, -1.163, -1.1571, -1.1511, -1.1451, -1.1414, -1.1376, -1.1339, -1.1302, -1.1264, -1.1227, -1.119, -1.1152, -1.1115, -1.1078, -1.104, -1.1003, -1.0966, -1.0929, -1.0891, -1.0854, -1.0817, -1.0779, -1.0742, -1.0705, -1.0667, -1.063, -1.0593, -1.0555, -1.0518, -1.0481, -1.0444, -1.0406, -1.0369, -1.0332, -1.0294, -1.0257, -1.022, -1.0182, -1.0145, -1.0108, -1.007, -1.0033, -0.9996, -0.9959, -0.9921, -0.9884, -0.9847, -0.9809, -0.9772, -0.9735, -0.9697, -0.966, -0.9623, -0.9585, -0.9548, -0.9511, -0.9474, -0.9436, -0.9399, -0.9362, -0.9324, -0.9287, -0.925, -0.9212, -0.9175, -0.9139, -0.9103, -0.9067, -0.9031, -0.8994, -0.8958, -0.8922, -0.8886, -0.885, -0.8814, -0.8778, -0.8742, -0.8705, -0.8669, -0.8633, -0.8597, -0.8561, -0.8525, -0.8489, -0.8453, -0.8416, -0.838, -0.8344, -0.8308, -0.8272, -0.8236, -0.82, -0.8164, -0.8127, -0.8091, -0.8055, -0.8019, -0.7983, -0.7947, -0.7911, -0.7875, -0.7839, -0.7802, -0.7766, -0.773, -0.7694, -0.7658, -0.7622, -0.7586, -0.755, -0.7513, -0.7477, -0.7441, -0.7405, -0.7369, -0.7333, -0.7297, -0.7261, -0.7224, -0.7188, -0.7152, -0.7116, -0.708, -0.7044, -0.7008, -0.6972, -0.6935, -0.6899, -0.6861, -0.6822, -0.6784, -0.6745, -0.6706, -0.6668, -0.6629, -0.6591, -0.6552, -0.6514, -0.6475, -0.6436, -0.6398, -0.6359, -0.6321, -0.6282, -0.6244, -0.6205, -0.6166, -0.6128, -0.6089, -0.6051, -0.6012, -0.5974, -0.5935, -0.5896, -0.5858, -0.5819, -0.5781, -0.5742, -0.5704, -0.5665, -0.5626, -0.5588, -0.5549, -0.5511, -0.5472, -0.5434, -0.5395, -0.5356, -0.5318, -0.5279, -0.5241, -0.5202, -0.5164, -0.5125, -0.5086, -0.5048, -0.5009, -0.4971, -0.4932, -0.4894, -0.4855, -0.4816, -0.4778, -0.4739, -0.4701, -0.4662, -0.4624, -0.46, -0.4576, -0.4552, -0.4529, -0.4505, -0.4481, -0.4458, -0.4434, -0.441, -0.4386, -0.4363, -0.4339, -0.4315, -0.4292, -0.4268, -0.4244, -0.4221, -0.4197, -0.4173, -0.4149, -0.4126, -0.4102, -0.4078, -0.4055, -0.4031, -0.4007, -0.3983, -0.396, -0.3936, -0.3912, -0.3889, -0.3865, -0.3841, -0.3818, -0.3794, -0.377, -0.3746, -0.3723, -0.3699, -0.3675, -0.3652, -0.3628, -0.3604, -0.358, -0.3557, -0.3533, -0.3509, -0.3486, -0.3462, -0.3438, -0.3415, -0.3391, -0.3367, -0.3343, -0.332, -0.3296, -0.3272, -0.3249, -0.3225, -0.3201, -0.3177, -0.3154, -0.313, -0.3106, -0.3083, -0.3059, -0.3035, -0.3012, -0.2988, -0.2964, -0.294, -0.2917, -0.2893, -0.2869, -0.2846, -0.2822, -0.2798, -0.2774, -0.2751, -0.2727, -0.2703, -0.268, -0.2656, -0.2632, -0.2609, -0.2585, -0.2561, -0.2537, -0.2514, -0.249, -0.2466, -0.2443, -0.2419, -0.2395, -0.2372, -0.2348, -0.2322, -0.2297, -0.2271, -0.2246, -0.222, -0.2194, -0.2169, -0.2143, -0.2118, -0.2092, -0.2067, -0.2041, -0.2015, -0.199, -0.1964, -0.1939, -0.1913, -0.1888, -0.1862, -0.1836, -0.1811, -0.1785, -0.176, -0.1734, -0.1709, -0.1683, -0.1657, -0.1632, -0.1606, -0.1581, -0.1555, -0.153, -0.1504, -0.1478, -0.1453, -0.1427, -0.1402, -0.1376, -0.1351, -0.1325, -0.1299, -0.1274, -0.1248, -0.1223, -0.1197, -0.1172, -0.1146, -0.112, -0.1095, -0.1069, -0.1044, -0.1018, -0.0993, -0.0967, -0.0941, -0.0916, -0.089, -0.0865, -0.0839, -0.0814, -0.0788, -0.0762, -0.0737, -0.0711, -0.0686, -0.066, -0.0635, -0.0609, -0.0583, -0.0558, -0.0532, -0.0507, -0.0481, -0.0456, -0.043, -0.0404, -0.0379, -0.0353, -0.0328, -0.0302, -0.0277, -0.0251, -0.0225, -0.02, -0.0174, -0.0149, -0.0123, -0.0098, -0.0072, -0.0046, -0.002, 0.0006, 0.0031, 0.0057, 0.0083, 0.0109, 0.0135, 0.0161, 0.0187, 0.0212, 0.0238, 0.0264, 0.029, 0.0316, 0.0342, 0.0368, 0.0393, 0.0419, 0.0445, 0.0471, 0.0497, 0.0523, 0.0549, 0.0574, 0.06, 0.0626, 0.0652, 0.0678, 0.0704, 0.073, 0.0756, 0.0781, 0.0807, 0.0833, 0.0859, 0.0885, 0.0911, 0.0937, 0.0962, 0.0988, 0.1014, 0.104, 0.1066, 0.1092, 0.1118, 0.1143, 0.1169, 0.1195, 0.1221, 0.1247, 0.1273, 0.1299, 0.1324, 0.135, 0.1376, 0.1402, 0.1428, 0.1454, 0.148, 0.1505, 0.1531, 0.1557, 0.1583, 0.1609, 0.1635, 0.1661, 0.1686, 0.1712, 0.1738, 0.1764, 0.179, 0.1816, 0.1842, 0.1868, 0.1893, 0.1919, 0.1945, 0.1971, 0.1997, 0.2023, 0.2049, 0.2074, 0.21, 0.2126, 0.2152, 0.2178, 0.2204, 0.2223, 0.2242, 0.2261, 0.228, 0.2299, 0.2318, 0.2338, 0.2357, 0.2376, 0.2395, 0.2414, 0.2433, 0.2452, 0.2471, 0.2491, 0.251, 0.2529, 0.2548, 0.2567, 0.2586, 0.2605, 0.2624, 0.2644, 0.2663, 0.2682, 0.2701, 0.272, 0.2739, 0.2758, 0.2777, 0.2797, 0.2816, 0.2835, 0.2854, 0.2873, 0.2892, 0.2911, 0.293, 0.295, 0.2969, 0.2988, 0.3007, 0.3026, 0.3045, 0.3064, 0.3083, 0.3103, 0.3122, 0.3141, 0.316, 0.3179, 0.3198, 0.3217, 0.3236, 0.3256, 0.3275, 0.3294, 0.3313, 0.3332, 0.3351, 0.337, 0.3389, 0.3409, 0.3428, 0.3447, 0.3466, 0.3485, 0.3504, 0.3523, 0.3542, 0.3562, 0.3581, 0.36, 0.3619, 0.3638, 0.3657, 0.3676, 0.3695, 0.3715, 0.3734, 0.3753, 0.3772, 0.3791, 0.381, 0.3829, 0.3848, 0.3868, 0.3887, 0.3906, 0.3925, 0.3944, 0.3963, 0.3982, 0.4001, 0.402, 0.404, 0.4059, 0.4078, 0.4097, 0.4116, 0.4135, 0.4154, 0.4173, 0.4193, 0.4212, 0.4231, 0.425, 0.4269, 0.4288, 0.4307, 0.4326, 0.4346, 0.4365, 0.4384, 0.4403, 0.4422, 0.4441, 0.446, 0.4479, 0.4511, 0.4543, 0.4574, 0.4606, 0.4638, 0.4669, 0.4701, 0.4732, 0.4764, 0.4796, 0.4827, 0.4859, 0.489, 0.4922, 0.4954, 0.4985, 0.5017, 0.5048, 0.508, 0.5112, 0.5143, 0.5175, 0.5206, 0.5238, 0.527, 0.5301, 0.5333, 0.5364, 0.5396, 0.5428, 0.5459, 0.5491, 0.5523, 0.5554, 0.5586, 0.5617, 0.5649, 0.5681, 0.5712, 0.5744, 0.5775, 0.5807, 0.5839, 0.587, 0.5902, 0.5933, 0.5965, 0.5997, 0.6028, 0.606, 0.6091, 0.6123, 0.6155, 0.6186, 0.6218, 0.625, 0.6281, 0.6313, 0.6344, 0.6376, 0.6408, 0.6439, 0.6471, 0.6502, 0.6534, 0.6566, 0.6597, 0.6629, 0.666, 0.6692, 0.6724, 0.6755, 0.679, 0.6825, 0.686, 0.6895, 0.693, 0.6965, 0.7, 0.7035, 0.707, 0.7105, 0.714, 0.7175, 0.721, 0.7245, 0.728, 0.7315, 0.735, 0.7385, 0.742, 0.7455, 0.749, 0.7525, 0.756, 0.7596, 0.7631, 0.7666, 0.7701, 0.7736, 0.7771, 0.7806, 0.7841, 0.7876, 0.7911, 0.7946, 0.7981, 0.8016, 0.8051, 0.8086, 0.8121, 0.8156, 0.8191, 0.8226, 0.8261, 0.8296, 0.8331, 0.8366, 0.8401, 0.8436, 0.8471, 0.8506, 0.8541, 0.8576, 0.8611, 0.8646, 0.8681, 0.8716, 0.8751, 0.8786, 0.8821, 0.8856, 0.8891, 0.8926, 0.8961, 0.8996, 0.9031, 0.9085, 0.9139, 0.9194, 0.9248, 0.9302, 0.9356, 0.941, 0.9464, 0.9519, 0.9573, 0.9627, 0.9681, 0.9735, 0.979, 0.9844, 0.9898, 0.9952, 1.0006, 1.006, 1.0115, 1.0169, 1.0223, 1.0277, 1.0331, 1.0386, 1.044, 1.0494, 1.0548, 1.0602, 1.0657, 1.0711, 1.0765, 1.0819, 1.0873, 1.0927, 1.0982, 1.1036, 1.109, 1.1144, 1.1198, 1.1253, 1.1307, 1.1376, 1.1445, 1.1514, 1.1583, 1.1652, 1.1721, 1.1789, 1.1858, 1.1927, 1.1996, 1.2065, 1.2134, 1.2203, 1.2272, 1.2341, 1.241, 1.2479, 1.2548, 1.2617, 1.2686, 1.2755, 1.2824, 1.2893, 1.2962, 1.3031, 1.31, 1.3169, 1.3238, 1.3307, 1.3376, 1.3445, 1.3514, 1.3582, 1.3661, 1.3739, 1.3818, 1.3896, 1.3975, 1.4053, 1.4132, 1.421, 1.4289, 1.4367, 1.4446, 1.4524, 1.4603, 1.4681, 1.476, 1.4838, 1.4917, 1.4995, 1.5074, 1.5152, 1.523, 1.5309, 1.5387, 1.5466, 1.5544, 1.5623, 1.5701, 1.578, 1.5858, 1.5949, 1.604, 1.6131, 1.6222, 1.6313, 1.6404, 1.6495, 1.6586, 1.6678, 1.6769, 1.686, 1.6951, 1.7042, 1.7133, 1.7224, 1.7315, 1.7406, 1.7497, 1.7588, 1.7679, 1.777, 1.7861, 1.7952, 1.8043, 1.8134, 1.8309, 1.8484, 1.8659, 1.8834, 1.9009, 1.9184, 1.9359, 1.9534, 1.971, 1.9885, 2.006, 2.0235, 2.041, 2.0663, 2.0915, 2.1168, 2.1421, 2.1674, 2.1927, 2.218, 2.2433, 2.2686, 2.3444, 2.4203, 2.4961, 2.572, 2.6478, 2.7237, 2.8375, 2.9513])
_n, _bins, _patches = ax.hist(_hist_data, bins=30, histtype='bar', color='#1f77b4', edgecolor='#000000', linewidth=1.0, alpha=0.7, label='Normal(0,1)', zorder=1)

# Labels
ax.set_title('Single Histogram')
ax.set_xlabel('Value')
ax.set_ylabel('Count')

# Limits
ax.set_xlim(-3.99, 3.52)
ax.set_ylim(0.0, 124.95)

# Fonts
ax.title.set_fontsize(12.0)
ax.title.set_fontfamily('sans-serif')
ax.xaxis.label.set_fontsize(10.0)
ax.yaxis.label.set_fontsize(10.0)
ax.tick_params(labelsize=10.0)
ax.tick_params(direction='out', length=3.5, width=0.8)

# Spines
ax.spines['top'].set_linewidth(0.8)
ax.spines['right'].set_linewidth(0.8)
ax.spines['bottom'].set_linewidth(0.8)
ax.spines['left'].set_linewidth(0.8)

# Legend removed
if ax.get_legend() is not None:
    ax.get_legend().remove()

# Layout
fig.set_size_inches(7.0, 5.0)
fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Test 2 — Two overlaid histograms

# %%
rng = np.random.default_rng(7)

fig, ax = plt.subplots(figsize=(7, 5))

x1 = rng.normal(0, 1, 1000)
x2 = rng.normal(2, 0.5, 500)
ax.hist(x1, bins=30, alpha=0.7, label='A')
ax.hist(x2, bins=30, alpha=0.7, label='B')

ax.set_title('Overlaid Histograms')
ax.set_xlabel('Value')
ax.set_ylabel('Count')
ax.legend()

matplotly(fig)
# Out:
# VBox(children=(VBox(children=(HBox(children=(Button(description='Undo', disabled=True, icon='undo', layout=Lay…

# %%
rng = np.random.default_rng(7)

fig, ax = plt.subplots(figsize=(7, 5))

x1 = rng.normal(0, 1, 1000)
x2 = rng.normal(2, 0.5, 500)
# ax.hist(x1, bins=30, alpha=0.7, label='A')
# ax.hist(x2, bins=30, alpha=0.7, label='B')

ax.set_title('Overlaid Histograms')
ax.set_xlabel('Value')
ax.set_ylabel('Count')
ax.legend()

# Generated by matplotly v4

ax.hist([x1, x2],
    bins=30,
    histtype='bar',
    color=['#1f77b4', '#ff7f0e'],
    edgecolor='#000000',
    linewidth=1.0,
    alpha=0.7,
    label=['A', 'B'],
    rwidth=0.8)

# Labels
ax.set_title('Overlaid Histograms')
ax.set_xlabel('Value')
ax.set_ylabel('Count')

# Limits
ax.set_xlim(-3.56, 3.7)
ax.set_ylim(0.0, 124.95)

# Fonts
ax.title.set_fontsize(10.0)
ax.title.set_fontfamily('Arial')
ax.xaxis.label.set_fontsize(10.0)
ax.yaxis.label.set_fontsize(10.0)
ax.tick_params(labelsize=10.0)
ax.tick_params(direction='out', length=3.5, width=0.8)

# Spines
ax.spines['top'].set_visible(False)
ax.spines['top'].set_linewidth(0.8)
ax.spines['right'].set_visible(False)
ax.spines['right'].set_linewidth(0.8)
ax.spines['bottom'].set_linewidth(0.8)
ax.spines['left'].set_linewidth(0.8)

# Legend removed
if ax.get_legend() is not None:
    ax.get_legend().remove()

# Layout
fig.set_size_inches(4.0, 3.0)
fig.tight_layout()
# Out:
# /var/folders/2p/b8xvdtls7_q4vb7y2vv2kprw0000gn/T/ipykernel_90024/2231632584.py:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
rng = np.random.default_rng(7)

fig, ax = plt.subplots(figsize=(7, 5))

x1 = rng.normal(0, 1, 1000)
x2 = rng.normal(2, 0.5, 500)
ax.hist(x1, bins=30, alpha=0.7, label='A')
ax.hist(x2, bins=30, alpha=0.7, label='B')

ax.set_title('Overlaid Histograms')
ax.set_xlabel('Value')
ax.set_ylabel('Count')
ax.legend()

# Generated by matplotly v4

# Recreate histograms with updated params
from matplotlib.container import BarContainer as _BC
for _c in list(ax.containers):
    if isinstance(_c, _BC):
        for _p in _c: _p.remove()
ax.containers[:] = [_c for _c in ax.containers if not isinstance(_c, _BC)]

# Histogram: A
_edges_0 = np.array([-3.2514, -3.059, -2.8665, -2.674, -2.4815, -2.289, -2.0965, -1.904, -1.7116, -1.5191, -1.3266, -1.1341, -0.9416, -0.7491, -0.5566, -0.3641, -0.1717, 0.0208, 0.2133, 0.4058, 0.5983, 0.7908, 0.9833, 1.1757, 1.3682, 1.5607, 1.7532, 1.9457, 2.1382, 2.3307, 2.5231])
_d0 = np.repeat((_edges_0[:-1] + _edges_0[1:]) / 2, [1, 0, 2, 3, 1, 7, 15, 13, 28, 24, 33, 55, 53, 61, 70, 84, 104, 83, 67, 54, 62, 45, 43, 25, 24, 13, 11, 8, 6, 5])
ax.hist(_d0, bins=_edges_0, histtype='bar', color='#1f77b4', edgecolor='#000000', linewidth=1.0, alpha=0.7, label='A')

# Histogram: B
_edges_1 = np.array([0.6099, 0.7027, 0.7956, 0.8884, 0.9813, 1.0742, 1.167, 1.2599, 1.3528, 1.4456, 1.5385, 1.6313, 1.7242, 1.8171, 1.9099, 2.0028, 2.0957, 2.1885, 2.2814, 2.3743, 2.4671, 2.56, 2.6528, 2.7457, 2.8386, 2.9314, 3.0243, 3.1172, 3.21, 3.3029, 3.3958])
_d1 = np.repeat((_edges_1[:-1] + _edges_1[1:]) / 2, [1, 3, 3, 7, 5, 8, 13, 17, 19, 24, 27, 34, 30, 38, 32, 33, 38, 26, 26, 26, 17, 18, 14, 12, 10, 6, 0, 5, 3, 5])
ax.hist(_d1, bins=_edges_1, histtype='bar', color='#ff7f0e', edgecolor='#000000', linewidth=1.0, alpha=0.7, label='B')
# Replace _d0..._d1 with your original data variables

# Labels
ax.set_title('Overlaid Histograms')
ax.set_xlabel('Value')
ax.set_ylabel('Count')

# Limits
ax.set_xlim(-3.56, 3.7)
ax.set_ylim(0.0, 124.95)

# Fonts
ax.title.set_fontsize(12.0)
ax.title.set_fontfamily('sans-serif')
ax.xaxis.label.set_fontsize(10.0)
ax.yaxis.label.set_fontsize(10.0)
ax.tick_params(labelsize=10.0)
ax.tick_params(direction='out', length=3.5, width=0.8)

# Spines
ax.spines['top'].set_linewidth(0.8)
ax.spines['right'].set_linewidth(0.8)
ax.spines['bottom'].set_linewidth(0.8)
ax.spines['left'].set_linewidth(0.8)

# Layout
fig.set_size_inches(7.0, 5.0)
fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
rng = np.random.default_rng(7)

fig, ax = plt.subplots(figsize=(7, 5))

x1 = rng.normal(0, 1, 1000)
x2 = rng.normal(2, 0.5, 500)
ax.hist(x1, bins=30, alpha=0.7, label='A')
ax.hist(x2, bins=30, alpha=0.7, label='B')

ax.set_title('Overlaid Histograms')
ax.set_xlabel('Value')
ax.set_ylabel('Count')
ax.legend()

# Generated by matplotly

# Histogram: A
# ax.hist(<data>, bins=20,
#         histtype='bar',
#         color='#1f77b4',
#         edgecolor='#000000',
#         linewidth=0.4,
#         alpha=0.7,
#         label='A')

# Histogram: B
# ax.hist(<data>, bins=20,
#         histtype='bar',
#         color='#ff7f0e',
#         edgecolor='#000000',
#         linewidth=1.0,
#         alpha=0.7,
#         label='B')
ax.patches[20].set_facecolor('#ff7f0e')
ax.patches[21].set_facecolor('#ff7f0e')
ax.patches[22].set_facecolor('#ff7f0e')
ax.patches[23].set_facecolor('#ff7f0e')
ax.patches[24].set_facecolor('#ff7f0e')
ax.patches[25].set_facecolor('#ff7f0e')
ax.patches[26].set_facecolor('#ff7f0e')
ax.patches[27].set_facecolor('#ff7f0e')
ax.patches[28].set_facecolor('#ff7f0e')
ax.patches[29].set_facecolor('#ff7f0e')
ax.patches[30].set_facecolor('#ff7f0e')
ax.patches[31].set_facecolor('#ff7f0e')
ax.patches[32].set_facecolor('#ff7f0e')
ax.patches[33].set_facecolor('#ff7f0e')
ax.patches[34].set_facecolor('#ff7f0e')
ax.patches[35].set_facecolor('#ff7f0e')
ax.patches[36].set_facecolor('#ff7f0e')
ax.patches[37].set_facecolor('#ff7f0e')
ax.patches[38].set_facecolor('#ff7f0e')
ax.patches[39].set_facecolor('#ff7f0e')

# Labels
ax.set_xlabel('Value')
ax.set_ylabel('Count')

# Limits
ax.set_xlim(-3.57, 3.71)
ax.set_ylim(0.0, 177.45)

# Fonts
ax.title.set_fontsize(12.0)
ax.title.set_fontfamily('sans-serif')
ax.xaxis.label.set_fontsize(10.0)
ax.yaxis.label.set_fontsize(10.0)
ax.tick_params(labelsize=10.0)
ax.tick_params(direction='out', length=3.5, width=0.8)

# Spines
ax.spines['top'].set_visible(False)
ax.spines['top'].set_linewidth(0.8)
ax.spines['right'].set_visible(False)
ax.spines['right'].set_linewidth(0.8)
ax.spines['bottom'].set_linewidth(0.8)
ax.spines['left'].set_linewidth(0.8)

# Layout
fig.set_size_inches(4.7, 2.4)
fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
rng = np.random.default_rng(7)

fig, ax = plt.subplots(figsize=(7, 5))

x1 = rng.normal(0, 1, 1000)
x2 = rng.normal(2, 0.5, 500)
ax.hist(x1, bins=30, alpha=0.7, label='A')
ax.hist(x2, bins=30, alpha=0.7, label='B')

ax.set_title('Overlaid Histograms')
ax.set_xlabel('Value')
ax.set_ylabel('Count')
ax.legend()

# Generated by matplotly

# Histogram: A
_hist_data = np.array([-3.2514, -2.8632, -2.7662, -2.6691, -2.6044, -2.5397, -2.475, -2.2809, -2.2532, -2.2255, -2.1977, -2.17, -2.1423, -2.1145, -2.0868, -2.0739, -2.0609, -2.048, -2.0351, -2.0221, -2.0092, -1.9962, -1.9833, -1.9704, -1.9574, -1.9445, -1.9315, -1.9186, -1.9057, -1.8927, -1.8778, -1.8629, -1.8479, -1.833, -1.8181, -1.8031, -1.7882, -1.7733, -1.7583, -1.7434, -1.7285, -1.7135, -1.6986, -1.6921, -1.6857, -1.6792, -1.6727, -1.6663, -1.6598, -1.6533, -1.6468, -1.6404, -1.6339, -1.6274, -1.621, -1.6145, -1.608, -1.6016, -1.5951, -1.5886, -1.5821, -1.5757, -1.5692, -1.5627, -1.5563, -1.5498, -1.5433, -1.5369, -1.5304, -1.5239, -1.5174, -1.511, -1.5045, -1.4961, -1.4876, -1.4792, -1.4707, -1.4623, -1.4539, -1.4454, -1.437, -1.4286, -1.4201, -1.4117, -1.4032, -1.3948, -1.3864, -1.3779, -1.3695, -1.361, -1.3526, -1.3442, -1.3357, -1.3273, -1.3188, -1.3104, -1.3049, -1.2993, -1.2938, -1.2882, -1.2827, -1.2771, -1.2716, -1.266, -1.2605, -1.2549, -1.2494, -1.2439, -1.2383, -1.2328, -1.2272, -1.2217, -1.2161, -1.2106, -1.205, -1.1995, -1.1939, -1.1884, -1.1828, -1.1773, -1.1718, -1.1662, -1.1607, -1.1551, -1.1496, -1.144, -1.1385, -1.1329, -1.1274, -1.1218, -1.1163, -1.1129, -1.1095, -1.1061, -1.1027, -1.0993, -1.0959, -1.0925, -1.0891, -1.0857, -1.0822, -1.0788, -1.0754, -1.072, -1.0686, -1.0652, -1.0618, -1.0584, -1.055, -1.0516, -1.0482, -1.0448, -1.0414, -1.038, -1.0346, -1.0312, -1.0278, -1.0244, -1.0209, -1.0175, -1.0141, -1.0107, -1.0073, -1.0039, -1.0005, -0.9971, -0.9937, -0.9903, -0.9869, -0.9835, -0.9801, -0.9767, -0.9733, -0.9699, -0.9665, -0.9631, -0.9597, -0.9562, -0.9528, -0.9494, -0.946, -0.9426, -0.9392, -0.9358, -0.9324, -0.929, -0.9256, -0.9222, -0.9185, -0.9149, -0.9112, -0.9075, -0.9039, -0.9002, -0.8966, -0.8929, -0.8892, -0.8856, -0.8819, -0.8782, -0.8746, -0.8709, -0.8673, -0.8636, -0.8599, -0.8563, -0.8526, -0.8489, -0.8453, -0.8416, -0.838, -0.8343, -0.8306, -0.827, -0.8233, -0.8197, -0.816, -0.8123, -0.8087, -0.805, -0.8013, -0.7977, -0.794, -0.7904, -0.7867, -0.783, -0.7794, -0.7757, -0.772, -0.7684, -0.7647, -0.7611, -0.7574, -0.7537, -0.7501, -0.7464, -0.7427, -0.7391, -0.7354, -0.7318, -0.7281, -0.725, -0.7219, -0.7188, -0.7158, -0.7127, -0.7096, -0.7065, -0.7034, -0.7004, -0.6973, -0.6942, -0.6911, -0.688, -0.685, -0.6819, -0.6788, -0.6757, -0.6726, -0.6696, -0.6665, -0.6634, -0.6603, -0.6572, -0.6541, -0.6511, -0.648, -0.6449, -0.6418, -0.6387, -0.6357, -0.6326, -0.6295, -0.6264, -0.6233, -0.6203, -0.6172, -0.6141, -0.611, -0.6079, -0.6049, -0.6018, -0.5987, -0.5956, -0.5925, -0.5894, -0.5864, -0.5833, -0.5802, -0.5771, -0.574, -0.571, -0.5679, -0.5648, -0.5617, -0.5586, -0.5556, -0.5525, -0.5494, -0.5463, -0.5432, -0.5402, -0.5371, -0.534, -0.5313, -0.5285, -0.5258, -0.5231, -0.5203, -0.5176, -0.5149, -0.5121, -0.5094, -0.5066, -0.5039, -0.5012, -0.4984, -0.4957, -0.493, -0.4902, -0.4875, -0.4848, -0.482, -0.4793, -0.4766, -0.4738, -0.4711, -0.4684, -0.4656, -0.4629, -0.4602, -0.4574, -0.4547, -0.452, -0.4492, -0.4465, -0.4438, -0.441, -0.4383, -0.4356, -0.4328, -0.4301, -0.4274, -0.4246, -0.4219, -0.4192, -0.4164, -0.4137, -0.411, -0.4082, -0.4055, -0.4028, -0.4, -0.3973, -0.3946, -0.3918, -0.3891, -0.3864, -0.3836, -0.3809, -0.3782, -0.3754, -0.3727, -0.37, -0.3672, -0.3645, -0.3618, -0.359, -0.3563, -0.3536, -0.3508, -0.3481, -0.3454, -0.3426, -0.3399, -0.3377, -0.3354, -0.3332, -0.331, -0.3287, -0.3265, -0.3243, -0.322, -0.3198, -0.3176, -0.3153, -0.3131, -0.3109, -0.3086, -0.3064, -0.3042, -0.302, -0.2997, -0.2975, -0.2953, -0.293, -0.2908, -0.2886, -0.2863, -0.2841, -0.2819, -0.2796, -0.2774, -0.2752, -0.273, -0.2707, -0.2685, -0.2663, -0.264, -0.2618, -0.2596, -0.2573, -0.2551, -0.2529, -0.2506, -0.2484, -0.2462, -0.2439, -0.2417, -0.2395, -0.2373, -0.235, -0.2328, -0.2306, -0.2283, -0.2261, -0.2239, -0.2216, -0.2194, -0.2172, -0.2149, -0.2127, -0.2105, -0.2083, -0.206, -0.2038, -0.2016, -0.1993, -0.1971, -0.1949, -0.1926, -0.1904, -0.1882, -0.1859, -0.1837, -0.1815, -0.1792, -0.177, -0.1748, -0.1726, -0.1703, -0.1681, -0.1659, -0.1636, -0.1614, -0.1592, -0.1569, -0.1547, -0.1525, -0.1502, -0.148, -0.1458, -0.144, -0.1422, -0.1404, -0.1386, -0.1368, -0.135, -0.1332, -0.1314, -0.1296, -0.1278, -0.126, -0.1242, -0.1224, -0.1206, -0.1188, -0.117, -0.1152, -0.1134, -0.1116, -0.1098, -0.108, -0.1062, -0.1044, -0.1026, -0.1008, -0.0991, -0.0973, -0.0955, -0.0937, -0.0919, -0.0901, -0.0883, -0.0865, -0.0847, -0.0829, -0.0811, -0.0793, -0.0775, -0.0757, -0.0739, -0.0721, -0.0703, -0.0685, -0.0667, -0.0649, -0.0631, -0.0613, -0.0595, -0.0577, -0.0559, -0.0541, -0.0523, -0.0505, -0.0487, -0.0469, -0.0451, -0.0433, -0.0415, -0.0397, -0.0379, -0.0361, -0.0344, -0.0326, -0.0308, -0.029, -0.0272, -0.0254, -0.0236, -0.0218, -0.02, -0.0182, -0.0164, -0.0146, -0.0128, -0.011, -0.0092, -0.0074, -0.0056, -0.0038, -0.002, -0.0002, 0.0016, 0.0034, 0.0052, 0.007, 0.0088, 0.0106, 0.0124, 0.0142, 0.016, 0.0178, 0.0196, 0.0214, 0.0232, 0.025, 0.0268, 0.0286, 0.0303, 0.0321, 0.0339, 0.0357, 0.0375, 0.0393, 0.0411, 0.0429, 0.0447, 0.0465, 0.0483, 0.0508, 0.0532, 0.0557, 0.0582, 0.0606, 0.0631, 0.0655, 0.068, 0.0704, 0.0729, 0.0753, 0.0778, 0.0803, 0.0827, 0.0852, 0.0876, 0.0901, 0.0925, 0.095, 0.0975, 0.0999, 0.1024, 0.1048, 0.1073, 0.1097, 0.1122, 0.1147, 0.1171, 0.1196, 0.122, 0.1245, 0.1269, 0.1294, 0.1319, 0.1343, 0.1368, 0.1392, 0.1417, 0.1441, 0.1466, 0.1491, 0.1515, 0.154, 0.1564, 0.1589, 0.1613, 0.1638, 0.1663, 0.1687, 0.1712, 0.1736, 0.1761, 0.1785, 0.181, 0.1835, 0.1859, 0.1884, 0.1908, 0.1933, 0.1957, 0.1982, 0.2007, 0.2031, 0.2056, 0.208, 0.2105, 0.2129, 0.2154, 0.2179, 0.2203, 0.2228, 0.2252, 0.2277, 0.2301, 0.2326, 0.2351, 0.2375, 0.24, 0.2424, 0.2454, 0.2483, 0.2512, 0.2542, 0.2571, 0.2601, 0.263, 0.266, 0.2689, 0.2718, 0.2748, 0.2777, 0.2807, 0.2836, 0.2865, 0.2895, 0.2924, 0.2954, 0.2983, 0.3012, 0.3042, 0.3071, 0.3101, 0.313, 0.316, 0.3189, 0.3218, 0.3248, 0.3277, 0.3307, 0.3336, 0.3365, 0.3395, 0.3424, 0.3454, 0.3483, 0.3512, 0.3542, 0.3571, 0.3601, 0.363, 0.3659, 0.3689, 0.3718, 0.3748, 0.3777, 0.3807, 0.3836, 0.3865, 0.3895, 0.3924, 0.3954, 0.3983, 0.4012, 0.4042, 0.4071, 0.4101, 0.413, 0.4159, 0.4189, 0.4218, 0.4248, 0.4277, 0.4306, 0.4336, 0.4365, 0.4403, 0.444, 0.4477, 0.4515, 0.4552, 0.4589, 0.4627, 0.4664, 0.4701, 0.4739, 0.4776, 0.4813, 0.4851, 0.4888, 0.4925, 0.4963, 0.5, 0.5037, 0.5075, 0.5112, 0.5149, 0.5187, 0.5224, 0.5261, 0.5298, 0.5336, 0.5373, 0.541, 0.5448, 0.5485, 0.5522, 0.556, 0.5597, 0.5634, 0.5672, 0.5709, 0.5746, 0.5784, 0.5821, 0.5858, 0.5896, 0.5933, 0.597, 0.6008, 0.6045, 0.6082, 0.612, 0.6157, 0.6194, 0.6232, 0.6269, 0.6306, 0.6336, 0.6366, 0.6396, 0.6426, 0.6456, 0.6486, 0.6515, 0.6545, 0.6575, 0.6605, 0.6635, 0.6665, 0.6695, 0.6724, 0.6754, 0.6784, 0.6814, 0.6844, 0.6874, 0.6904, 0.6933, 0.6963, 0.6993, 0.7023, 0.7053, 0.7083, 0.7113, 0.7142, 0.7172, 0.7202, 0.7232, 0.7262, 0.7292, 0.7322, 0.7352, 0.7381, 0.7411, 0.7441, 0.7471, 0.7501, 0.7531, 0.7561, 0.759, 0.762, 0.765, 0.768, 0.771, 0.774, 0.777, 0.7799, 0.7829, 0.7859, 0.7889, 0.7919, 0.7949, 0.7979, 0.8008, 0.8038, 0.8068, 0.8098, 0.8128, 0.8158, 0.8188, 0.8218, 0.8247, 0.8295, 0.8342, 0.8389, 0.8437, 0.8484, 0.8531, 0.8579, 0.8626, 0.8673, 0.8721, 0.8768, 0.8815, 0.8863, 0.891, 0.8958, 0.9005, 0.9052, 0.91, 0.9147, 0.9194, 0.9242, 0.9289, 0.9336, 0.9384, 0.9431, 0.9478, 0.9526, 0.9573, 0.962, 0.9668, 0.9715, 0.9762, 0.981, 0.9857, 0.9904, 0.9952, 0.9999, 1.0046, 1.0094, 1.0141, 1.0188, 1.0233, 1.0277, 1.0321, 1.0365, 1.0409, 1.0453, 1.0497, 1.0541, 1.0585, 1.063, 1.0674, 1.0718, 1.0762, 1.0806, 1.085, 1.0894, 1.0938, 1.0982, 1.1027, 1.1071, 1.1115, 1.1159, 1.1203, 1.1247, 1.1291, 1.1335, 1.1379, 1.1424, 1.1468, 1.1512, 1.1556, 1.16, 1.1644, 1.1688, 1.1732, 1.1777, 1.1821, 1.1865, 1.1909, 1.1953, 1.1997, 1.2041, 1.2085, 1.2129, 1.2222, 1.2314, 1.2407, 1.2499, 1.2592, 1.2684, 1.2776, 1.2869, 1.2961, 1.3054, 1.3146, 1.3239, 1.3331, 1.3423, 1.3516, 1.3608, 1.3701, 1.3793, 1.3886, 1.3978, 1.407, 1.4148, 1.4226, 1.4303, 1.4381, 1.4459, 1.4536, 1.4614, 1.4692, 1.4769, 1.4847, 1.4925, 1.5002, 1.508, 1.5157, 1.5235, 1.5313, 1.539, 1.5468, 1.5546, 1.5623, 1.5701, 1.5779, 1.5856, 1.5934, 1.6012, 1.6227, 1.6443, 1.6659, 1.6874, 1.709, 1.7306, 1.7521, 1.7737, 1.7953, 1.8114, 1.8276, 1.8438, 1.86, 1.8761, 1.8923, 1.9085, 1.9247, 1.9408, 1.957, 1.9732, 1.9894, 2.0171, 2.0448, 2.0725, 2.1003, 2.128, 2.1557, 2.1835, 2.2158, 2.2482, 2.2805, 2.3129, 2.3452, 2.3776, 2.4261, 2.4746, 2.5231])
_n, _bins, _patches = ax.hist(_hist_data, bins=29, histtype='stepfilled', color='#1f77b4', edgecolor='#000000', linewidth=1.0, alpha=0.7, label='A', zorder=1, density=True)

# Histogram: B
_hist_data = np.array([0.6099, 0.7033, 0.7345, 0.7657, 0.7968, 0.828, 0.8592, 0.8903, 0.9037, 0.917, 0.9304, 0.9437, 0.9571, 0.9704, 0.9838, 1.0025, 1.0212, 1.0399, 1.0586, 1.0773, 1.089, 1.1007, 1.1123, 1.124, 1.1357, 1.1474, 1.1591, 1.1708, 1.178, 1.1852, 1.1923, 1.1995, 1.2067, 1.2139, 1.2211, 1.2283, 1.2355, 1.2427, 1.2499, 1.2571, 1.2643, 1.2698, 1.2753, 1.2808, 1.2863, 1.2918, 1.2973, 1.3028, 1.3083, 1.3138, 1.3193, 1.3248, 1.3302, 1.3357, 1.3412, 1.3467, 1.3522, 1.3577, 1.3624, 1.3671, 1.3718, 1.3764, 1.3811, 1.3858, 1.3905, 1.3951, 1.3998, 1.4045, 1.4092, 1.4138, 1.4185, 1.4232, 1.4279, 1.4325, 1.4372, 1.4419, 1.4466, 1.4512, 1.4551, 1.459, 1.4629, 1.4668, 1.4707, 1.4746, 1.4785, 1.4824, 1.4863, 1.4902, 1.4941, 1.498, 1.5019, 1.5058, 1.5097, 1.5136, 1.5175, 1.5213, 1.5252, 1.5291, 1.533, 1.5369, 1.5408, 1.5447, 1.5481, 1.5514, 1.5547, 1.5581, 1.5614, 1.5648, 1.5681, 1.5714, 1.5748, 1.5781, 1.5814, 1.5848, 1.5881, 1.5915, 1.5948, 1.5981, 1.6015, 1.6048, 1.6082, 1.6115, 1.6148, 1.6182, 1.6215, 1.6249, 1.6282, 1.6315, 1.6349, 1.6382, 1.641, 1.6437, 1.6465, 1.6492, 1.652, 1.6547, 1.6575, 1.6602, 1.663, 1.6657, 1.6685, 1.6712, 1.674, 1.6767, 1.6794, 1.6822, 1.6849, 1.6877, 1.6904, 1.6932, 1.6959, 1.6987, 1.7014, 1.7042, 1.7069, 1.7097, 1.7124, 1.7152, 1.7179, 1.7207, 1.7234, 1.7262, 1.7289, 1.7317, 1.7348, 1.7379, 1.741, 1.7442, 1.7473, 1.7504, 1.7535, 1.7566, 1.7597, 1.7629, 1.766, 1.7691, 1.7722, 1.7753, 1.7784, 1.7816, 1.7847, 1.7878, 1.7909, 1.794, 1.7971, 1.8002, 1.8034, 1.8065, 1.8096, 1.8127, 1.8158, 1.8189, 1.8221, 1.8252, 1.8276, 1.83, 1.8324, 1.8348, 1.8372, 1.8396, 1.842, 1.8444, 1.8468, 1.8491, 1.8515, 1.8539, 1.8563, 1.8587, 1.8611, 1.8635, 1.8659, 1.8683, 1.8707, 1.8731, 1.8755, 1.8779, 1.8803, 1.8827, 1.8851, 1.8875, 1.8899, 1.8923, 1.8947, 1.8971, 1.8995, 1.9019, 1.9043, 1.9067, 1.9091, 1.9115, 1.9139, 1.9163, 1.9187, 1.9216, 1.9245, 1.9274, 1.9304, 1.9333, 1.9362, 1.9391, 1.942, 1.945, 1.9479, 1.9508, 1.9537, 1.9566, 1.9596, 1.9625, 1.9654, 1.9683, 1.9713, 1.9742, 1.9771, 1.98, 1.9829, 1.9859, 1.9888, 1.9917, 1.9946, 1.9975, 2.0005, 2.0034, 2.0063, 2.0092, 2.0122, 2.015, 2.0178, 2.0207, 2.0235, 2.0263, 2.0291, 2.032, 2.0348, 2.0376, 2.0405, 2.0433, 2.0461, 2.049, 2.0518, 2.0546, 2.0575, 2.0603, 2.0631, 2.066, 2.0688, 2.0716, 2.0745, 2.0773, 2.0801, 2.083, 2.0858, 2.0886, 2.0915, 2.0943, 2.0971, 2.1, 2.1028, 2.1056, 2.108, 2.1104, 2.1128, 2.1152, 2.1176, 2.12, 2.1224, 2.1248, 2.1272, 2.1296, 2.132, 2.1344, 2.1368, 2.1392, 2.1416, 2.144, 2.1464, 2.1488, 2.1512, 2.1536, 2.156, 2.1584, 2.1608, 2.1632, 2.1656, 2.168, 2.1704, 2.1728, 2.1752, 2.1776, 2.1799, 2.1823, 2.1847, 2.1871, 2.1895, 2.1919, 2.1943, 2.1967, 2.1991, 2.203, 2.2069, 2.2108, 2.2147, 2.2186, 2.2225, 2.2264, 2.2303, 2.2342, 2.2381, 2.242, 2.2459, 2.2498, 2.2537, 2.2576, 2.2614, 2.2653, 2.2692, 2.2731, 2.277, 2.2809, 2.2848, 2.2887, 2.2926, 2.2961, 2.2995, 2.303, 2.3065, 2.3099, 2.3134, 2.3168, 2.3203, 2.3238, 2.3272, 2.3307, 2.3342, 2.3376, 2.3411, 2.3445, 2.348, 2.3515, 2.3549, 2.3584, 2.3619, 2.3653, 2.3688, 2.3722, 2.3757, 2.3792, 2.3826, 2.3861, 2.3897, 2.3933, 2.3969, 2.4005, 2.4041, 2.4077, 2.4113, 2.4149, 2.4185, 2.4221, 2.4256, 2.4292, 2.4328, 2.4364, 2.44, 2.4436, 2.4472, 2.4508, 2.4544, 2.458, 2.4616, 2.4652, 2.4688, 2.4724, 2.476, 2.4796, 2.4854, 2.4913, 2.4971, 2.503, 2.5088, 2.5146, 2.5205, 2.5263, 2.5322, 2.538, 2.5439, 2.5497, 2.5555, 2.5614, 2.5672, 2.5731, 2.5783, 2.5835, 2.5887, 2.5938, 2.599, 2.6042, 2.6094, 2.6146, 2.6198, 2.625, 2.6302, 2.6354, 2.6406, 2.6458, 2.651, 2.6562, 2.6614, 2.6666, 2.6732, 2.6799, 2.6866, 2.6933, 2.6999, 2.7066, 2.7133, 2.72, 2.7267, 2.7333, 2.74, 2.7467, 2.7534, 2.76, 2.7685, 2.777, 2.7855, 2.794, 2.8025, 2.811, 2.8195, 2.828, 2.8365, 2.845, 2.8535, 2.8629, 2.8722, 2.8816, 2.8909, 2.9003, 2.9096, 2.919, 2.9283, 2.9377, 2.947, 2.9657, 2.9844, 3.0031, 3.0218, 3.134, 3.1496, 3.1652, 3.1807, 3.1963, 3.2119, 3.2275, 3.2742, 3.321, 3.3397, 3.3584, 3.3771, 3.3958])
_n, _bins, _patches = ax.hist(_hist_data, bins=29, histtype='stepfilled', color='#ff7f0e', edgecolor='#000000', linewidth=1.0, alpha=0.7, label='B', zorder=1, density=True)

# Labels
ax.set_title('Overlaid Histograms')
ax.set_xlabel('Value')
ax.set_ylabel('Count')

# Limits
ax.set_xlim(-3.58, 3.73)
ax.set_ylim(0.0, 0.83)

# Fonts
ax.title.set_fontsize(12.0)
ax.title.set_fontfamily('sans-serif')
ax.xaxis.label.set_fontsize(10.0)
ax.yaxis.label.set_fontsize(10.0)
ax.tick_params(labelsize=10.0)
ax.tick_params(direction='out', length=3.5, width=0.8)

# Spines
ax.spines['top'].set_linewidth(0.8)
ax.spines['right'].set_linewidth(0.8)
ax.spines['bottom'].set_linewidth(0.8)
ax.spines['left'].set_linewidth(0.8)

# Legend
handles, labels = ax.get_legend_handles_labels()
for h, lbl in zip(handles, ['A', 'B']):
    h.set_label(lbl)
ax.legend(loc='upper right', frameon=False, fontsize=10.0, bbox_to_anchor=(1.0, 1.0))

# Layout
fig.set_size_inches(7.0, 5.0)
fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Test 3 — High bin count + different distribution

# %%
rng = np.random.default_rng(99)

fig, ax = plt.subplots(figsize=(7, 5))

# Bimodal distribution
x = np.concatenate([
    rng.normal(-2, 0.8, 600),
    rng.normal(3, 1.2, 400),
])
ax.hist(x, bins=50, alpha=0.7, edgecolor='white', label='Bimodal')

ax.set_title('Bimodal Distribution (50 bins)')
ax.set_xlabel('Value')
ax.set_ylabel('Count')
ax.legend()

matplotly(fig)
# Out:
# VBox(children=(VBox(children=(HBox(children=(Button(description='Undo', disabled=True, icon='undo', layout=Lay…

# %% [markdown]
# ## Test 4 — Three histograms with different spreads

# %%
rng = np.random.default_rng(123)

fig, ax = plt.subplots(figsize=(7, 5))

for label, mu, sigma, n in [
    ('Control', 0, 1, 800),
    ('Treatment A', 1.5, 0.6, 500),
    ('Treatment B', -1, 1.5, 600),
]:
    ax.hist(rng.normal(mu, sigma, n), bins=25, alpha=0.5, label=label)

ax.set_title('Experiment Results')
ax.set_xlabel('Measurement')
ax.set_ylabel('Count')
ax.legend()

matplotly(fig)
# Out:
# VBox(children=(VBox(children=(HBox(children=(Button(description='Undo', disabled=True, icon='undo', layout=Lay…

# %%
rng = np.random.default_rng(123)

fig, ax = plt.subplots(figsize=(7, 5))

for label, mu, sigma, n in [
    ('Control', 0, 1, 800),
    ('Treatment A', 1.5, 0.6, 500),
    ('Treatment B', -1, 1.5, 600),
]:
#     ax.hist(rng.normal(mu, sigma, n), bins=25, alpha=0.5, label=label)

ax.set_title('Experiment Results')
ax.set_xlabel('Measurement')
ax.set_ylabel('Count')
ax.legend()

# Generated by matplotly v4

# Merged histograms — replace your separate ax.hist() calls with:
# ax.hist([<Control>, <Treatment A>, <Treatment B>],
#     bins=25,
#     histtype='bar',
#     color=['#1f77b4', '#ff7f0e', '#2ca02c'],
#     edgecolor='#000000',
#     linewidth=1.0,
#     alpha=0.5,
#     label=['Control', 'Treatment A', 'Treatment B'],
#     rwidth=0.8)

# Histogram: Control
for _p in ax.containers[0]:
    _p.set_facecolor('#1f77b4')
    _p.set_edgecolor('#000000')
    _p.set_alpha(0.5)

# Histogram: Treatment A
for _p in ax.containers[1]:
    _p.set_facecolor('#ff7f0e')
    _p.set_edgecolor('#000000')
    _p.set_alpha(0.5)

# Histogram: Treatment B
for _p in ax.containers[2]:
    _p.set_facecolor('#2ca02c')
    _p.set_edgecolor('#000000')
    _p.set_alpha(0.5)

# Labels
ax.set_title('Experiment Results')
ax.set_xlabel('Measurement')
ax.set_ylabel('Count')

# Limits
ax.set_xlim(-5.29, 3.59)
ax.set_ylim(0.0, 118.65)

# Fonts
ax.title.set_fontsize(10.0)
ax.title.set_fontfamily('Arial')
ax.xaxis.label.set_fontsize(10.0)
ax.yaxis.label.set_fontsize(10.0)
ax.tick_params(labelsize=10.0)
ax.tick_params(direction='out', length=3.5, width=0.8)

# Spines
ax.spines['top'].set_visible(False)
ax.spines['top'].set_linewidth(0.8)
ax.spines['right'].set_visible(False)
ax.spines['right'].set_linewidth(0.8)
ax.spines['bottom'].set_linewidth(0.8)
ax.spines['left'].set_linewidth(0.8)

# Legend
ax.legend(loc='upper right', frameon=False, fontsize=10.0, bbox_to_anchor=(1.0, 1.0))

# Layout
fig.set_size_inches(4.0, 3.0)
fig.tight_layout()
# Out:
#   Cell In[8], line 12
#     ax.set_title('Experiment Results')
#     ^
# IndentationError: expected an indented block
