# %%
# %matplotlib widget

# %%
import sys
sys.path.insert(0, '.')

import numpy as np
import matplotlib.pyplot as plt
from matplotly import matplotly

# %%
# Fake data: damped sine wave
x = np.linspace(0, 4 * np.pi, 200)
y = np.exp(-0.15 * x) * np.sin(x)

x2 = np.linspace(0, 4 * np.pi, 200)
y2 = np.exp(-0.15 * x) * np.sin(x+1.2)

x3 = np.linspace(0, 4 * np.pi, 200)
y3 = np.exp(-0.15 * x) * np.sin(x+2)

fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(x, y, label='damped sine', linewidth=1.5)
ax.plot(x2, y2, label='damped sine', linewidth=1.5)
ax.plot(x3, y3, label='damped sine', linewidth=1.5)
ax.set_title('Damped Oscillation')
ax.set_xlabel('Time (s)')
ax.set_ylabel('Amplitude')


matplotly(fig)

# %%
# Fake data: damped sine wave
x = np.linspace(0, 4 * np.pi, 200)
y = np.exp(-0.15 * x) * np.sin(x)

x2 = np.linspace(0, 4 * np.pi, 200)
y2 = np.exp(-0.15 * x) * np.sin(x+1.2)

x3 = np.linspace(0, 4 * np.pi, 200)
y3 = np.exp(-0.15 * x) * np.sin(x+2)

fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(x, y, label='damped sine', linewidth=1.5)
ax.plot(x2, y2, label='damped sine', linewidth=1.5)
ax.plot(x3, y3, label='damped sine', linewidth=1.5)
ax.set_title('Damped Oscillation')
ax.set_xlabel('Time (s)')
ax.set_ylabel('Amplitude')

# Generated by matplotly v4

_lines = [l for l in ax.lines if not l.get_label().startswith('_')]

# damped sine
_lines[0].set_color('#1b9e77')
_lines[0].set_linewidth(1.5)

# damped sine
_lines[1].set_color('#d95f02')
_lines[1].set_linewidth(1.5)

# damped sine
_lines[2].set_color('#a6761d')
_lines[2].set_linewidth(1.5)
_lines[2].set_alpha(0.25)

# Labels
ax.set_title('Damped Oscillation')
ax.set_xlabel('Time (s)')
ax.set_ylabel('Amplitude')

# Limits
ax.set_xlim(-0.63, 13.19)
ax.set_ylim(-0.75, 1.04)

# Fonts
ax.title.set_fontsize(10.0)
ax.title.set_fontfamily('Arial')
ax.xaxis.label.set_fontsize(10.0)
ax.yaxis.label.set_fontsize(10.0)
ax.tick_params(labelsize=10.0)
ax.tick_params(direction='out', length=3.5, width=0.8)

# Spines
ax.spines['top'].set_visible(False)
ax.spines['top'].set_linewidth(0.8)
ax.spines['right'].set_visible(False)
ax.spines['right'].set_linewidth(0.8)
ax.spines['bottom'].set_linewidth(0.8)
ax.spines['left'].set_linewidth(0.8)

# Legend
ax.legend(loc='upper right', frameon=False, fontsize=10.0, bbox_to_anchor=(1.0, 1.0))

# Layout
fig.set_size_inches(3.6, 3.0)
fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Fake data: damped sine wave
x = np.linspace(0, 4 * np.pi, 200)
y = np.exp(-0.15 * x) * np.sin(x)

x2 = np.linspace(0, 4 * np.pi, 200)
y2 = np.exp(-0.15 * x) * np.sin(x+1.2)

fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(x, y, label='damped sine', linewidth=1.5)
ax.plot(x2, y2, label='damped sine', linewidth=1.5)
ax.set_title('Damped Oscillation')
ax.set_xlabel('Time (s)')
ax.set_ylabel('Amplitude')

# Generated by plotbuild

# damped sine
ax.lines[0].set_color('#1f77b4')
ax.lines[0].set_linewidth(1.5)
ax.lines[0].set_linestyle('-.')
ax.lines[0].set_alpha(0.6)

# damped sine
ax.lines[1].set_color('#2ca02c')
ax.lines[1].set_linewidth(1.5)
ax.lines[1].set_linestyle(':')

# Labels
ax.set_title('Damped Oscillation')
ax.set_xlabel('Time (s)')
ax.set_ylabel('Amplitude')

# Fonts
ax.title.set_fontsize(10.0)
ax.title.set_fontfamily('Arial')
ax.xaxis.label.set_fontsize(10.0)
ax.yaxis.label.set_fontsize(10.0)
ax.tick_params(labelsize=10.0)
ax.tick_params(direction='out', length=3.5, width=0.8)

# Spines
ax.spines['top'].set_visible(False)
ax.spines['top'].set_linewidth(0.8)
ax.spines['right'].set_visible(False)
ax.spines['right'].set_linewidth(0.8)
ax.spines['bottom'].set_linewidth(0.8)
ax.spines['left'].set_linewidth(0.8)

# Legend
handles, labels = ax.get_legend_handles_labels()
for h, lbl in zip(handles, ['damped sine', 'damped sine']):
    h.set_label(lbl)
ax.legend(loc='upper right', frameon=False, fontsize=10.0, bbox_to_anchor=(0.78, 1.0))

# Layout
fig.set_size_inches(4.0, 2.75)

# Generated by plotbuild

# damped sine
ax.lines[0].set_color('#1f77b4')
ax.lines[0].set_linewidth(1.5)
ax.lines[0].set_linestyle('-.')
ax.lines[0].set_alpha(0.6)

# damped sine
ax.lines[1].set_color('#2ca02c')
ax.lines[1].set_linewidth(1.5)
ax.lines[1].set_linestyle(':')

# Labels
ax.set_title('Damped Oscillation')
ax.set_xlabel('Time (s)')
ax.set_ylabel('Amplitude')

# Fonts
ax.title.set_fontsize(10.0)
ax.title.set_fontfamily('Arial')
ax.xaxis.label.set_fontsize(10.0)
ax.yaxis.label.set_fontsize(10.0)
ax.tick_params(labelsize=10.0)
ax.tick_params(direction='out', length=3.5, width=0.8)

# Spines
ax.spines['top'].set_visible(False)
ax.spines['top'].set_linewidth(0.8)
ax.spines['right'].set_visible(False)
ax.spines['right'].set_linewidth(0.8)
ax.spines['bottom'].set_linewidth(0.8)
ax.spines['left'].set_linewidth(0.8)

# Legend
handles, labels = ax.get_legend_handles_labels()
for h, lbl in zip(handles, ['damped sine', 'damped sine']):
    h.set_label(lbl)
ax.legend(loc='upper right', frameon=False, fontsize=10.0, bbox_to_anchor=(0.78, 1.0))

# Layout
fig.set_size_inches(4.0, 2.75)
fig.set_dpi(200.0)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Fake data: damped sine wave
x = np.linspace(0, 4 * np.pi, 200)
y = np.exp(-0.15 * x) * np.sin(x)

x2 = np.linspace(0, 4 * np.pi, 200)
y2 = np.exp(-0.15 * x) * np.sin(x+1.2)

fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(x, y, label='damped sine', linewidth=1.5)
ax.plot(x2, y2, label='damped sine', linewidth=1.5)
ax.set_title('Damped Oscillation')
ax.set_xlabel('Time (s)')
ax.set_ylabel('Amplitude')
ax.legend()

# Generated by plotbuild

# damped sine
ax.lines[0].set_color('#2ca02c')
ax.lines[0].set_linewidth(1.5)

# damped sine
ax.lines[1].set_color('#ff7f0e')
ax.lines[1].set_linewidth(1.5)

# Fonts
ax.title.set_fontsize(12.0)
ax.title.set_fontfamily('sans-serif')
ax.xaxis.label.set_fontsize(10.0)
ax.yaxis.label.set_fontsize(10.0)
ax.tick_params(labelsize=10.0)
ax.tick_params(direction='out', length=3.5, width=0.8)

# Spines
ax.spines['top'].set_linewidth(0.8)
ax.spines['right'].set_linewidth(0.8)
ax.spines['bottom'].set_linewidth(0.8)
ax.spines['left'].set_linewidth(0.8)

# Legend
handles, labels = ax.get_legend_handles_labels()
for h, lbl in zip(handles, ['damped sine', 'damped sine']):
    h.set_label(lbl)
ax.legend(loc='upper right', frameon=False, fontsize=10.0, ncol=6.0, bbox_to_anchor=(0.66, 1.0))

# Layout
fig.set_size_inches(8.0, 4.0)
matplotly(fig)

# %%
# Fake data: damped sine wave
x = np.linspace(0, 4 * np.pi, 200)
y = np.exp(-0.15 * x) * np.sin(x)

x2 = np.linspace(0, 4 * np.pi, 200)
y2 = np.exp(-0.15 * x) * np.sin(x+1.2)

fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(x, y, label='damped sine', linewidth=1.5)
ax.plot(x2, y2, label='damped sine', linewidth=1.5)
ax.set_title('Damped Oscillation')
ax.set_xlabel('Time (s)')
ax.set_ylabel('Amplitude')
ax.legend()

# Generated by plotbuild

# damped sine
ax.lines[0].set_color('#2ca02c')
ax.lines[0].set_linewidth(1.5)

# damped sine
ax.lines[1].set_color('#ff7f0e')
ax.lines[1].set_linewidth(1.5)

# Fonts
ax.title.set_fontsize(12.0)
ax.title.set_fontfamily('sans-serif')
ax.xaxis.label.set_fontsize(10.0)
ax.yaxis.label.set_fontsize(10.0)
ax.tick_params(labelsize=10.0)
ax.tick_params(direction='out', length=3.5, width=0.8)

# Spines
ax.spines['top'].set_linewidth(0.8)
ax.spines['right'].set_linewidth(0.8)
ax.spines['bottom'].set_linewidth(0.8)
ax.spines['left'].set_linewidth(0.8)

# Legend
handles, labels = ax.get_legend_handles_labels()
for h, lbl in zip(handles, ['damped sine', 'damped sine']):
    h.set_label(lbl)
ax.legend(loc='upper right', frameon=False, fontsize=10.0, ncol=6.0, bbox_to_anchor=(0.66, 1.0))

# Layout
fig.set_size_inches(8.0, 4.0)

# Generated by plotbuild

# damped sine
ax.lines[0].set_color('#2ca02c')
ax.lines[0].set_linewidth(1.5)

# damped sine
ax.lines[1].set_color('#ff7f0e')
ax.lines[1].set_linewidth(1.5)

# Fonts
ax.title.set_fontsize(12.0)
ax.title.set_fontfamily('sans-serif')
ax.xaxis.label.set_fontsize(10.0)
ax.yaxis.label.set_fontsize(10.0)
ax.tick_params(labelsize=10.0)
ax.tick_params(direction='out', length=3.5, width=0.8)

# Spines
ax.spines['top'].set_visible(False)
ax.spines['top'].set_linewidth(0.8)
ax.spines['right'].set_visible(False)
ax.spines['right'].set_linewidth(0.8)
ax.spines['bottom'].set_linewidth(0.8)
ax.spines['left'].set_linewidth(0.8)

# Legend
handles, labels = ax.get_legend_handles_labels()
for h, lbl in zip(handles, ['damped sine', 'damped sine']):
    h.set_label(lbl)
ax.legend(loc='upper right', frameon=False, fontsize=10.0, ncol=6.0, bbox_to_anchor=(0.66, 1.0))

# Layout
fig.set_size_inches(8.0, 4.0)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
