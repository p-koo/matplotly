# %%
# %matplotlib widget

# %%
import sys
sys.path.insert(0, '.')

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotly import matplotly

# %% [markdown]
# ## Test 1 — Pure scatter (two groups)

# %%
rng = np.random.default_rng(42)

fig, ax = plt.subplots(figsize=(7, 5))

# Group A: clustered around (2, 3)
n_a = 60
x_a = rng.normal(2, 0.8, n_a)
y_a = rng.normal(3, 1.0, n_a)
ax.scatter(x_a, y_a, s=40, alpha=0.7, label='Group A')

# Group B: clustered around (5, 6)
n_b = 50
x_b = rng.normal(5, 1.2, n_b)
y_b = rng.normal(6, 0.9, n_b)
ax.scatter(x_b, y_b, s=55, alpha=0.7, label='Group B')

ax.set_title('Two Clusters')
ax.set_xlabel('Feature 1')
ax.set_ylabel('Feature 2')
ax.legend()

matplotly(fig)

# %%
rng = np.random.default_rng(42)

fig, ax = plt.subplots(figsize=(7, 5))

# Group A: clustered around (2, 3)
n_a = 60
x_a = rng.normal(2, 0.8, n_a)
y_a = rng.normal(3, 1.0, n_a)
ax.scatter(x_a, y_a, s=40, alpha=0.7, label='Group A')

# Group B: clustered around (5, 6)
n_b = 50
x_b = rng.normal(5, 1.2, n_b)
y_b = rng.normal(6, 0.9, n_b)
ax.scatter(x_b, y_b, s=55, alpha=0.7, label='Group B')

ax.set_title('Two Clusters')
ax.set_xlabel('Feature 1')
ax.set_ylabel('Feature 2')
ax.legend()

# Generated by matplotly v4

from matplotlib.collections import PathCollection as _PC
_scatter = [c for c in ax.collections if isinstance(c, _PC)]
_scatter[0].set_facecolor('#1f77b4')
_scatter[0].set_edgecolor('#1f77b4')
_scatter[0].set_alpha(0.7)
_scatter[0].set_sizes([40.0])
_scatter[1].set_facecolor('#ff7f0e')
_scatter[1].set_edgecolor('#ff7f0e')
_scatter[1].set_alpha(0.7)
_scatter[1].set_sizes([55.0])

# Labels
ax.set_title('Two Clusters')
ax.set_xlabel('Feature 1')
ax.set_ylabel('Feature 2')

# Limits
ax.set_xlim(0.04, 8.9)
ax.set_ylim(0.04, 8.9)

# Fonts
ax.title.set_fontsize(10.0)
ax.title.set_fontfamily('Arial')
ax.xaxis.label.set_fontsize(10.0)
ax.yaxis.label.set_fontsize(10.0)
ax.tick_params(labelsize=10.0)
ax.tick_params(direction='out', length=3.5, width=0.8)
ax.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(2.0))
ax.yaxis.set_major_locator(matplotlib.ticker.MultipleLocator(2.0))

# Spines
ax.spines['top'].set_visible(False)
ax.spines['top'].set_linewidth(0.8)
ax.spines['right'].set_visible(False)
ax.spines['right'].set_linewidth(0.8)
ax.spines['bottom'].set_linewidth(0.8)
ax.spines['left'].set_linewidth(0.8)

# Legend
ax.legend(loc='upper right', frameon=False, fontsize=10.0, handletextpad=0.0, bbox_to_anchor=(1.0, 0.38))

# Layout
fig.set_size_inches(3.6, 3.6)
fig.tight_layout()

# Marginal histograms
_pos = ax.get_position()
_fig_w, _fig_h = fig.get_size_inches()
_x0, _y0, _w, _h = _pos.x0, _pos.y0, _pos.width, _pos.height
_h -= (1.0 + 0) / _fig_h
_w -= (1.0 + 0) / _fig_w
ax.set_position([_x0, _y0, _w, _h])
_m_data = [ax.collections[0].get_offsets()[:, 0], ax.collections[1].get_offsets()[:, 0]]
_m_bins = np.histogram_bin_edges(np.concatenate(_m_data), bins=20)
_pos = ax.get_position()
_fig_w, _fig_h = fig.get_size_inches()
_h_frac = 1.0 / _fig_h
_pad = 0 / _fig_h
_m_rect = [_pos.x0, _pos.y1 + _pad, _pos.width, _h_frac]
ax_m = fig.add_axes(_m_rect, sharex=ax)
ax_m.hist(_m_data[0], bins=_m_bins, color='#1f77b4', alpha=0.5, edgecolor='none')
ax_m.hist(_m_data[1], bins=_m_bins, color='#ff7f0e', alpha=0.5, edgecolor='none')
ax_m.spines['top'].set_visible(False)
ax_m.spines['right'].set_visible(False)
ax_m.tick_params(axis='x', bottom=False, top=False, labelbottom=False, labeltop=False)
ax_m.tick_params(axis='y', left=True, labelleft=True, right=False, labelright=False, labelsize=10.0)
_m_data = [ax.collections[0].get_offsets()[:, 1], ax.collections[1].get_offsets()[:, 1]]
_m_bins = np.histogram_bin_edges(np.concatenate(_m_data), bins=20)
_pos = ax.get_position()
_fig_w, _fig_h = fig.get_size_inches()
_w_frac = 1.0 / _fig_w
_pad = 0 / _fig_w
_m_rect = [_pos.x1 + _pad, _pos.y0, _w_frac, _pos.height]
ax_m = fig.add_axes(_m_rect, sharey=ax)
ax_m.hist(_m_data[0], bins=_m_bins, color='#1f77b4', alpha=0.5, edgecolor='none', orientation='horizontal')
ax_m.hist(_m_data[1], bins=_m_bins, color='#ff7f0e', alpha=0.5, edgecolor='none', orientation='horizontal')
ax_m.spines['top'].set_visible(False)
ax_m.spines['right'].set_visible(False)
ax_m.tick_params(axis='y', left=False, right=False, labelleft=False, labelright=False)
ax_m.tick_params(axis='x', bottom=True, labelbottom=True, top=False, labeltop=False, labelsize=10.0)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
rng = np.random.default_rng(42)

fig, ax = plt.subplots(figsize=(7, 5))

# Group A: clustered around (2, 3)
n_a = 60
x_a = rng.normal(2, 0.8, n_a)
y_a = rng.normal(3, 1.0, n_a)
ax.scatter(x_a, y_a, s=40, alpha=0.7, label='Group A')

# Group B: clustered around (5, 6)
n_b = 50
x_b = rng.normal(5, 1.2, n_b)
y_b = rng.normal(6, 0.9, n_b)
ax.scatter(x_b, y_b, s=55, alpha=0.7, label='Group B')

ax.set_title('Two Clusters')
ax.set_xlabel('Feature 1')
ax.set_ylabel('Feature 2')
ax.legend()

# Generated by matplotly
ax.collections[0].set_facecolor('#1f77b4')
ax.collections[1].set_facecolor('#ff7f0e')

# Labels
ax.set_xlabel('Text')
ax.set_ylabel('features')

# Limits
ax.set_xlim(0.04, 8.9)
ax.set_ylim(0.04, 8.9)

# Fonts
ax.title.set_fontsize(12.0)
ax.title.set_fontfamily('sans-serif')
ax.xaxis.label.set_fontsize(10.0)
ax.yaxis.label.set_fontsize(10.0)
ax.tick_params(labelsize=10.0)
ax.tick_params(direction='out', length=3.5, width=0.8)
ax.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(1.0))
ax.yaxis.set_major_locator(matplotlib.ticker.MultipleLocator(1.0))

# Spines
ax.spines['top'].set_linewidth(0.8)
ax.spines['right'].set_linewidth(0.8)
ax.spines['bottom'].set_linewidth(0.8)
ax.spines['left'].set_linewidth(0.8)

# Legend
handles, labels = ax.get_legend_handles_labels()
for h, lbl in zip(handles, ['Group A1', 'Group B']):
    h.set_label(lbl)
ax.legend(loc='lower right', frameon=False, fontsize=10.0, handletextpad=0.0, handleheight=1.3, bbox_to_anchor=(0.96, 0.02))

# Layout
fig.set_size_inches(5.0, 5.0)
fig.tight_layout()

# Marginal histograms
_pos = ax.get_position()
_fig_w, _fig_h = fig.get_size_inches()
_x0, _y0, _w, _h = _pos.x0, _pos.y0, _pos.width, _pos.height
_h -= (1.0 + 0) / _fig_h
_w -= (1.0 + 0) / _fig_w
ax.set_position([_x0, _y0, _w, _h])
_m_data = [ax.collections[0].get_offsets()[:, 0], ax.collections[1].get_offsets()[:, 0]]
_m_bins = np.histogram_bin_edges(np.concatenate(_m_data), bins=20)
_pos = ax.get_position()
_fig_w, _fig_h = fig.get_size_inches()
_h_frac = 1.0 / _fig_h
_pad = 0 / _fig_h
_m_rect = [_pos.x0, _pos.y1 + _pad, _pos.width, _h_frac]
ax_m = fig.add_axes(_m_rect, sharex=ax)
ax_m.hist(_m_data[0], bins=_m_bins, color='#1f77b4', alpha=0.5, edgecolor='none')
ax_m.hist(_m_data[1], bins=_m_bins, color='#ff7f0e', alpha=0.5, edgecolor='none')
ax_m.spines['top'].set_visible(False)
ax_m.spines['right'].set_visible(False)
ax_m.tick_params(axis='x', bottom=False, top=False, labelbottom=False, labeltop=False)
ax_m.tick_params(axis='y', left=True, labelleft=True, right=False, labelright=False, labelsize=10.0)
_m_data = [ax.collections[0].get_offsets()[:, 1], ax.collections[1].get_offsets()[:, 1]]
_m_bins = np.histogram_bin_edges(np.concatenate(_m_data), bins=20)
_pos = ax.get_position()
_fig_w, _fig_h = fig.get_size_inches()
_w_frac = 1.0 / _fig_w
_pad = 0 / _fig_w
_m_rect = [_pos.x1 + _pad, _pos.y0, _w_frac, _pos.height]
ax_m = fig.add_axes(_m_rect, sharey=ax)
ax_m.hist(_m_data[0], bins=_m_bins, color='#1f77b4', alpha=0.5, edgecolor='none', orientation='horizontal')
ax_m.hist(_m_data[1], bins=_m_bins, color='#ff7f0e', alpha=0.5, edgecolor='none', orientation='horizontal')
ax_m.spines['top'].set_visible(False)
ax_m.spines['right'].set_visible(False)
ax_m.tick_params(axis='y', left=False, right=False, labelleft=False, labelright=False)
ax_m.tick_params(axis='x', bottom=True, labelbottom=True, top=False, labeltop=False, labelsize=10.0)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Test 2 — Mixed line + scatter

# %%
rng = np.random.default_rng(7)

x = np.linspace(0, 10, 200)
y_true = 2.5 * np.sin(x) + 0.5 * x

# Noisy observations
n_obs = 40
x_obs = rng.uniform(0, 10, n_obs)
y_obs = 2.5 * np.sin(x_obs) + 0.5 * x_obs + rng.normal(0, 1.0, n_obs)

fig, ax = plt.subplots(figsize=(8, 4.5))
ax.plot(x, y_true, linewidth=2, label='True signal')
ax.scatter(x_obs, y_obs, s=35, zorder=5, label='Observations')

ax.set_title('Signal vs. Noisy Observations')
ax.set_xlabel('Time (s)')
ax.set_ylabel('Amplitude')
ax.legend()

matplotly(fig)

# %%
rng = np.random.default_rng(7)

x = np.linspace(0, 10, 200)
y_true = 2.5 * np.sin(x) + 0.5 * x

# Noisy observations
n_obs = 40
x_obs = rng.uniform(0, 10, n_obs)
y_obs = 2.5 * np.sin(x_obs) + 0.5 * x_obs + rng.normal(0, 1.0, n_obs)

fig, ax = plt.subplots(figsize=(8, 4.5))
ax.plot(x, y_true, linewidth=2, label='True signal')
ax.scatter(x_obs, y_obs, s=35, zorder=5, label='Observations')

ax.set_title('Signal vs. Noisy Observations')
ax.set_xlabel('Time (s)')
ax.set_ylabel('Amplitude')
ax.legend()

# Generated by matplotly

# True signal
ax.lines[0].set_color('#d62728')
ax.lines[0].set_linewidth(2.0)
ax.lines[0].set_linestyle('--')
ax.collections[0].set_facecolor('#1f77b4')

# Labels
ax.set_title('Signal vs. Noisy Observations')
ax.set_xlabel('Time (s)')
ax.set_ylabel('Amplitude')

# Limits
ax.set_xlim(-0.5, 10.5)
ax.set_ylim(-2.09, 7.76)

# Fonts
ax.title.set_fontsize(12.0)
ax.title.set_fontfamily('sans-serif')
ax.xaxis.label.set_fontsize(10.0)
ax.yaxis.label.set_fontsize(10.0)
ax.tick_params(labelsize=10.0)
ax.tick_params(direction='out', length=3.5, width=0.8)

# Spines
ax.spines['top'].set_visible(False)
ax.spines['top'].set_linewidth(0.8)
ax.spines['right'].set_visible(False)
ax.spines['right'].set_linewidth(0.8)
ax.spines['bottom'].set_linewidth(0.8)
ax.spines['left'].set_linewidth(0.8)

# Legend
handles, labels = ax.get_legend_handles_labels()
for h, lbl in zip(handles, ['True signal', 'Observations']):
    h.set_label(lbl)
ax.legend(loc='best', frameon=False, fontsize=10.0)

# Layout
fig.set_size_inches(5.0, 3.6)
fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Test 3 — Three scatter groups with varying size

# %%
rng = np.random.default_rng(123)

fig, ax = plt.subplots(figsize=(7, 5))

for i, (label, center, size) in enumerate([
    ('Control', (1, 4), 30),
    ('Treatment A', (4, 7), 50),
    ('Treatment B', (6, 2), 70),
]):
    n = 45
    x = rng.normal(center[0], 1.0, n)
    y = rng.normal(center[1], 1.2, n)
    ax.scatter(x, y, s=size, alpha=0.65, edgecolors='white',
              linewidths=0.8, label=label)

ax.set_title('Experiment Results')
ax.set_xlabel('Dose (mg)')
ax.set_ylabel('Response')
ax.legend()

matplotly(fig)
